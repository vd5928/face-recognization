# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\abdul\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\abdul\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\abdul\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abdul\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abdul\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abdul\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abdul\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\abdul\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdul\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six in c:\users\abdul\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
faceCascade=cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
image = cv2.imread("brth.jpg")

# %%
from matplotlib import pyplot as plt
plt.imshow(image)

# %%
RGB_img = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
GR_img = cv2.cvtColor(RGB_img,cv2.COLOR_BGR2GRAY)
plt.imshow(GR_img)

# %%
faces = faceCascade.detectMultiScale(
      GR_img,
    scaleFactor = 1.3,
    minNeighbors = 5,
    minSize=(30,30)
)
print(faces)
# Out:
# [[385  52  61  61]
#  [304  99  58  58]
#  [161 162  57  57]]

# %%
image = cv2.imread("brth.jpg")
for(x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),5)
RGB_img = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
ims = []
for(x,y,w,h) in faces:
    crop = RGB_img[y:y+h,x:x+w]
    ims.append(crop)

# %%
plt.imshow(ims[0])

# %%
plt.imshow(ims[1])

# %%
plt.imshow(ims[2])
